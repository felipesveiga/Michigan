# %%
import pandas as pd
df = pd.read_csv('Admission_Predict (1).csv')
df.rename(mapper = str.strip, axis =1, inplace = True)
df.rename(mapper = str.casefold, axis =1, inplace = True)
df.where(df['toefl score'] > 105).dropna()
df.where(df['toefl score'] > 105)

df[df['toefl score'] > 105]

df[(df['toefl score'].isin(range(106, 115)))]['toefl score'].unique()

(df['toefl score'] > 105) & (df['toefl score'] < 115)
toefl = df['toefl score']
for score in toefl.iteritems():
    print(score)
# Out:
# (0, 118)
# (1, 107)
# (2, 104)
# (3, 110)
# (4, 103)
# (5, 115)
# (6, 109)
# (7, 101)
# (8, 102)
# (9, 108)
# (10, 106)
# (11, 111)
# (12, 112)
# (13, 109)
# (14, 104)
# (15, 105)
# (16, 107)
# (17, 106)
# (18, 110)
# (19, 102)
# (20, 107)
# (21, 114)
# (22, 116)
# (23, 119)
# (24, 119)
# (25, 120)
# (26, 109)
# (27, 98)
# (28, 93)
# (29, 99)
# (30, 97)
# (31, 103)
# (32, 118)
# (33, 114)
# (34, 112)
# (35, 110)
# (36, 106)
# (37, 105)
# (38, 105)
# (39, 108)
# (40, 110)
# (41, 105)
# (42, 107)
# (43, 117)
# (44, 113)
# (45, 110)
# (46, 114)
# (47, 119)
# (48, 110)
# (49, 111)
# (50, 98)
# (51, 100)
# (52, 116)
# (53, 112)
# (54, 110)
# (55, 103)
# (56, 102)
# (57, 99)
# (58, 99)
# (59, 104)
# (60, 100)
# (61, 101)
# (62, 105)
# (63, 107)
# (64, 111)
# (65, 112)
# (66, 114)
# (67, 107)
# (68, 109)
# (69, 115)
# (70, 118)
# (71, 112)
# (72, 111)
# (73, 108)
# (74, 106)
# (75, 114)
# (76, 112)
# (77, 99)
# (78, 95)
# (79, 93)
# (80, 105)
# (81, 120)
# (82, 110)
# (83, 115)
# (84, 115)
# ...

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)
obj2['California'] == None
# Out:
# False

# %%
pd.read_csv('claa)
